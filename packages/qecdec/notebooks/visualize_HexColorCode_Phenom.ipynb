# %%
from qecdec.experiments import HexColorCode_Phenom_Memory

# %%
def draw_tiles(expmt: HexColorCode_Phenom_Memory, scaling: float = 20):
    import drawsvg as draw

    width = (max(q.real for q in expmt.sites) + 2) * scaling
    height = (max(q.imag for q in expmt.sites) + 2) * scaling

    d = draw.Drawing(width, height, origin=(-scaling, -scaling))

    colors = ["red", "green", "blue"]

    for t in expmt.tiles:
        p = draw.Path(fill=colors[t.color], stroke="black")
        p.M(t.sites[0].real * scaling, t.sites[0].imag * scaling)
        for q in t.sites[1:]:
            p.L(q.real * scaling, q.imag * scaling)
        p.Z()
        d.append(p)

    for q in expmt.sites:
        d.append(
            draw.Circle(
                cx=q.real * scaling,
                cy=q.imag * scaling,
                r=0.3 * scaling,
                fill="black",
            )
        )
        d.append(
            draw.Text(
                str(expmt.site2ind[q]),
                font_size=0.5 * scaling,
                x=q.real * scaling,
                y=q.imag * scaling,
                center=True,
                fill="white",
            )
        )

    return d

# %%
expmt = HexColorCode_Phenom_Memory(
    d=3,
    rounds=7,
    basis="Z",
    depolarizing_error_rate=0.001,
    meas_error_rate=0.005,
)

draw_tiles(expmt)

# %%
expmt.circuit.diagram("timeline")
# Out:
# <svg viewBox="0 0 3680 544"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L3648,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L3648,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L3648,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L3648,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L3648,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L3648,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L3648,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# </g>
# <rect x="80" y="48" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="64">COORDS(0,0)</text>
# <rect x="80" y="112" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="128">COORDS(1,1)</text>
# <rect x="80" y="176" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="192">COORDS(2,1)</text>
# <rect x="80" y="240" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="256">COORDS(2,3)</text>
# <rect x="80" y="304" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="320">COORDS(3,0)</text>
# <rect x="80" y="368" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="384">COORDS(3,2)</text>
# <rect x="80" y="432" width="224" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="192" y="448">COORDS(4,0)</text>
# <path d="M352,64 L352,448 " stroke="black"/>
# <rect x="336" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="352" y="44">rec[0]</text>
# <rect x="336" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="336" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="336" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="336" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="336" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="336" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="352" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="400" y="48" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="480" y="64">OBS_INCLUDE(0)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="480" y="44">L0 *= rec[0]</text>
# <path d="M68,40 L68,32 L572,32 L572,40 " stroke="black" fill="none"/>
# <path d="M68,504 L68,512 L572,512 L572,504 " stroke="black" fill="none"/>
# <path d="M608,64 L608,320 " stroke="black"/>
# <rect x="592" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="608" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="608" y="44">rec[1]</text>
# <rect x="592" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="608" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="592" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="608" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="592" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="608" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M672,192 L672,448 " stroke="black"/>
# <rect x="656" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="672" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="672" y="172">rec[2]</text>
# <rect x="656" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="672" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="656" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="672" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="656" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="672" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M736,128 L736,384 " stroke="black"/>
# <rect x="720" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="736" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="736" y="108">rec[3]</text>
# <rect x="720" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="736" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="720" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="736" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="720" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="736" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M800,64 L800,320 " stroke="black"/>
# <rect x="784" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="800" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="800" y="44">rec[4]</text>
# <rect x="784" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="800" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="784" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="800" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="784" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="800" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <path d="M864,192 L864,448 " stroke="black"/>
# <rect x="848" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="864" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="864" y="172">rec[5]</text>
# <rect x="848" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="864" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="848" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="864" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="848" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="864" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <path d="M928,128 L928,384 " stroke="black"/>
# <rect x="912" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="928" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="928" y="108">rec[6]</text>
# <rect x="912" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="928" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="912" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="928" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="912" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="928" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <path d="M580,40 L580,32 L956,32 L956,40 " stroke="black" fill="none"/>
# <path d="M580,504 L580,512 L956,512 L956,504 " stroke="black" fill="none"/>
# <path d="M1000,32 L992,32 L992,512 L1000,512 " stroke="black" fill="none"/>
# <text dominant-baseline="auto" text-anchor="start" font-family="monospace" font-size="12" x="996" y="508">REP6</text>
# <rect x="1040" y="48" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="64">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="84">0.001</text>
# <rect x="1040" y="112" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="128">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="148">0.001</text>
# <rect x="1040" y="176" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="192">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="212">0.001</text>
# <rect x="1040" y="240" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="256">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="276">0.001</text>
# <rect x="1040" y="304" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="320">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="340">0.001</text>
# <rect x="1040" y="368" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="384">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="404">0.001</text>
# <rect x="1040" y="432" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1056" y="448">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1056" y="468">0.001</text>
# <path d="M1120,64 L1120,320 " stroke="black"/>
# <rect x="1104" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1120" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1120" y="44">rec[7+iter*6]</text>
# <rect x="1104" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1120" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1104" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1120" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1104" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1120" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1120" y="340">0.005</text>
# <path d="M1184,192 L1184,448 " stroke="black"/>
# <rect x="1168" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1184" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1184" y="172">rec[8+iter*6]</text>
# <rect x="1168" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1184" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1168" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1184" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1168" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1184" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1184" y="468">0.005</text>
# <path d="M1248,128 L1248,384 " stroke="black"/>
# <rect x="1232" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1248" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1248" y="108">rec[9+iter*6]</text>
# <rect x="1232" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1248" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1232" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1248" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="1232" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1248" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1248" y="404">0.005</text>
# <path d="M1312,64 L1312,320 " stroke="black"/>
# <rect x="1296" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1312" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1312" y="44">rec[10+iter*6]</text>
# <rect x="1296" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1312" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1296" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1312" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1296" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1312" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1312" y="340">0.005</text>
# <path d="M1376,192 L1376,448 " stroke="black"/>
# <rect x="1360" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1376" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1376" y="172">rec[11+iter*6]</text>
# <rect x="1360" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1376" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1360" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1376" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1360" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1376" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1376" y="468">0.005</text>
# <path d="M1440,128 L1440,384 " stroke="black"/>
# <rect x="1424" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1440" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1440" y="108">rec[12+iter*6]</text>
# <rect x="1424" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1440" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1424" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1440" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="1424" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="1440" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="1440" y="404">0.005</text>
# <rect x="1424" y="48" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1536" y="64">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="1536" y="84">coords=(1.5,0.5,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1536" y="44">D[0+iter*6] = rec[7+iter*6]*rec[1+iter*6]</text>
# <rect x="1680" y="176" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1792" y="192">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="212">coords=(3,0.75,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="172">D[1+iter*6] = rec[8+iter*6]*rec[2+iter*6]</text>
# <rect x="1680" y="112" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1792" y="128">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="148">coords=(2,1.75,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="108">D[2+iter*6] = rec[9+iter*6]*rec[3+iter*6]</text>
# <rect x="1680" y="48" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1792" y="64">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="84">coords=(1.5,0.5,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1792" y="44">D[3+iter*6] = rec[10+iter*6]*rec[4+iter*6]</text>
# <rect x="1936" y="176" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2048" y="192">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2048" y="212">coords=(3,0.75,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2048" y="172">D[4+iter*6] = rec[11+iter*6]*rec[5+iter*6]</text>
# <rect x="1936" y="112" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2048" y="128">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2048" y="148">coords=(2,1.75,0+iter)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2048" y="108">D[5+iter*6] = rec[12+iter*6]*rec[6+iter*6]</text>
# <path d="M1092,40 L1092,32 L2172,32 L2172,40 " stroke="black" fill="none"/>
# <path d="M1092,504 L1092,512 L2172,512 L2172,504 " stroke="black" fill="none"/>
# <path d="M2200,32 L2208,32 L2208,512 L2200,512 " stroke="black" fill="none"/>
# <rect x="2256" y="48" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="64">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="84">0.001</text>
# <rect x="2256" y="112" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="128">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="148">0.001</text>
# <rect x="2256" y="176" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="192">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="212">0.001</text>
# <rect x="2256" y="240" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="256">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="276">0.001</text>
# <rect x="2256" y="304" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="320">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="340">0.001</text>
# <rect x="2256" y="368" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="384">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="404">0.001</text>
# <rect x="2256" y="432" width="32" height="32" stroke="black" fill="pink"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2272" y="448">DEP<tspan baseline-shift="sub" font-size="10">1</tspan></text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="10" stroke="red" x="2272" y="468">0.001</text>
# <path d="M2336,64 L2336,320 " stroke="black"/>
# <rect x="2320" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2336" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2336" y="44">rec[43]</text>
# <rect x="2320" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2336" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2320" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2336" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2320" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2336" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M2400,192 L2400,448 " stroke="black"/>
# <rect x="2384" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2400" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2400" y="172">rec[44]</text>
# <rect x="2384" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2400" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2384" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2400" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2384" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2400" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M2464,128 L2464,384 " stroke="black"/>
# <rect x="2448" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2464" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2464" y="108">rec[45]</text>
# <rect x="2448" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2464" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2448" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2464" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <rect x="2448" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2464" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">X</tspan></text>
# <path d="M2528,64 L2528,320 " stroke="black"/>
# <rect x="2512" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2528" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2528" y="44">rec[46]</text>
# <rect x="2512" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2528" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2512" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2528" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2512" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2528" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <path d="M2592,192 L2592,448 " stroke="black"/>
# <rect x="2576" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2592" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2592" y="172">rec[47]</text>
# <rect x="2576" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2592" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2576" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2592" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2576" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2592" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <path d="M2656,128 L2656,384 " stroke="black"/>
# <rect x="2640" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2656" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2656" y="108">rec[48]</text>
# <rect x="2640" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2656" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2640" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2656" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2640" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="2656" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="2640" y="48" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2752" y="64">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="2752" y="84">coords=(1.5,0.5,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2752" y="44">D36 = rec[43]*rec[37]</text>
# <rect x="2896" y="176" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3008" y="192">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="212">coords=(3,0.75,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="172">D37 = rec[44]*rec[38]</text>
# <rect x="2896" y="112" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3008" y="128">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="148">coords=(2,1.75,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="108">D38 = rec[45]*rec[39]</text>
# <rect x="2896" y="48" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3008" y="64">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="84">coords=(1.5,0.5,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3008" y="44">D39 = rec[46]*rec[40]</text>
# <rect x="3152" y="176" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3264" y="192">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="3264" y="212">coords=(3,0.75,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3264" y="172">D40 = rec[47]*rec[41]</text>
# <rect x="3152" y="112" width="224" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3264" y="128">DETECTOR</text>
# <text dominant-baseline="hanging" text-anchor="middle" font-family="monospace" font-size="8" x="3264" y="148">coords=(2,1.75,6)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3264" y="108">D41 = rec[48]*rec[42]</text>
# <path d="M2308,40 L2308,32 L3388,32 L3388,40 " stroke="black" fill="none"/>
# <path d="M2308,504 L2308,512 L3388,512 L3388,504 " stroke="black" fill="none"/>
# <path d="M3424,64 L3424,448 " stroke="black"/>
# <rect x="3408" y="48" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="64" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3424" y="44">rec[49]</text>
# <rect x="3408" y="112" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="128" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3408" y="176" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="192" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3408" y="240" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="256" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3408" y="304" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="320" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3408" y="368" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="384" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3408" y="432" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="12" x="3424" y="448" fill="white">MPP<tspan baseline-shift="sub" font-size="10">Z</tspan></text>
# <rect x="3472" y="48" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="3552" y="64">OBS_INCLUDE(0)</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="3552" y="44">L0 *= rec[49]</text>
# <path d="M3396,40 L3396,32 L3644,32 L3644,40 " stroke="black" fill="none"/>
# <path d="M3396,504 L3396,512 L3644,512 L3644,504 " stroke="black" fill="none"/>
# </svg>
