# %%
# %reload_ext autoreload
# %autoreload 2
from qecdec.experiments import RotatedSurfaceCode_Memory
from qecdec.decoders import MWPMDecoder, BPDecoder
from qecdec.slwin import SlidingWindowDecoder
from utils import get_stats, bar_plot_stats, stacked_bar_plot_stats
import numpy as np

# %% [markdown]
# # Fixed number of rounds, varying physical error rate

# %%
d = 5
rounds = 20
window_size = 5
commit_size = 1
bp_iters = 50
shots = 10_000
seed = 42
error_rates = [0.004, 0.006, 0.008, 0.01, 0.012]

# %%
results = {}

for p in error_rates:
    category = "p={:.3f}".format(p)
    print("Collecting data for {}".format(category))

    # Set up the experiment.
    expmt = RotatedSurfaceCode_Memory(
        d,
        rounds,
        basis="Z",
        data_qubit_error_rate=p,
        meas_error_rate=p,
    )

    # Sample data.
    sampler = expmt.circuit.compile_detector_sampler(seed=seed)
    syndromes, observables = sampler.sample(shots, separate_observables=True)
    syndromes, observables = syndromes.astype(np.uint8), observables.astype(np.uint8)

    # Randomly generate gamma.
    rng = np.random.default_rng(42)
    gamma = rng.uniform(-0.1, 0.8, expmt.num_error_mechanisms)

    # Set up the decoders.
    bp = BPDecoder(expmt.chkmat, expmt.prior, max_iter=bp_iters)
    mwpm = MWPMDecoder(expmt.chkmat, expmt.prior)
    sw = SlidingWindowDecoder.from_pcm_prior(
        expmt.chkmat,
        expmt.prior,
        detectors_per_layer=expmt.num_detectors_per_layer,
        window_size=window_size,
        commit_size=commit_size,
    )

    # Decode.
    print("Decoding with BP...")
    ehat_bp = bp.decode_batch(syndromes)
    print("Decoding with BP(SW)...")
    sw.configure_inner_decoders("BP", max_iter=bp_iters)
    ehat_bp_sw = sw.decode_batch(syndromes)
    print("Decoding with DMemBP(SW)...")
    sw.configure_inner_decoders("DMemBP", gamma=gamma, max_iter=bp_iters)
    ehat_dmembp_sw = sw.decode_batch(syndromes)
    print("Decoding with MWPM...")
    ehat_mwpm = mwpm.decode_batch(syndromes)
    print("Decoding with MWPM(SW)...")
    sw.configure_inner_decoders("MWPM")
    ehat_mwpm_sw = sw.decode_batch(syndromes)

    # Get stats and store results.
    print("Getting stats...")
    results[category] = {
        "BP": get_stats(expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_bp),
        "BP(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_bp_sw
        ),
        "DMemBP(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_dmembp_sw
        ),
        "MWPM": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_mwpm
        ),
        "MWPM(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_mwpm_sw
        ),
    }
    print("-" * 100)

print("Data collection complete!")
# Out:
# Collecting data for p=0.004
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for p=0.006
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for p=0.008
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for p=0.010
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for p=0.012
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Data collection complete!

# %%
bar_plot_stats(results)

# %%
stacked_bar_plot_stats(results)

# %% [markdown]
# # Fixed physical error rate, varying number of rounds

# %%
d = 5
rounds_options = [10, 20, 30, 40, 50]
window_size = 5
commit_size = 1
bp_iters = 50
shots = 10_000
seed = 42
p = 0.01

# %%
results = {}

for rounds in rounds_options:
    category = "rounds={}".format(rounds)
    print("Collecting data for {}".format(category))

    # Set up the experiment.
    expmt = RotatedSurfaceCode_Memory(
        d,
        rounds,
        basis="Z",
        data_qubit_error_rate=p,
        meas_error_rate=p,
    )

    # Sample data.
    sampler = expmt.circuit.compile_detector_sampler(seed=seed)
    syndromes, observables = sampler.sample(shots, separate_observables=True)
    syndromes, observables = syndromes.astype(np.uint8), observables.astype(np.uint8)
    # Randomly generate gamma.
    rng = np.random.default_rng(42)
    gamma = rng.uniform(-0.1, 0.8, expmt.num_error_mechanisms)

    # Set up the decoders.
    bp = BPDecoder(expmt.chkmat, expmt.prior, max_iter=bp_iters)
    mwpm = MWPMDecoder(expmt.chkmat, expmt.prior)
    sw = SlidingWindowDecoder.from_pcm_prior(
        expmt.chkmat,
        expmt.prior,
        detectors_per_layer=expmt.num_detectors_per_layer,
        window_size=window_size,
        commit_size=commit_size,
    )

    # Decode.
    print("Decoding with BP...")
    ehat_bp = bp.decode_batch(syndromes)
    print("Decoding with BP(SW)...")
    sw.configure_inner_decoders("BP", max_iter=bp_iters)
    ehat_bp_sw = sw.decode_batch(syndromes)
    print("Decoding with DMemBP(SW)...")
    sw.configure_inner_decoders("DMemBP", gamma=gamma, max_iter=bp_iters)
    ehat_dmembp_sw = sw.decode_batch(syndromes)
    print("Decoding with MWPM...")
    ehat_mwpm = mwpm.decode_batch(syndromes)
    print("Decoding with MWPM(SW)...")
    sw.configure_inner_decoders("MWPM")
    ehat_mwpm_sw = sw.decode_batch(syndromes)

    # Get stats and store results.
    print("Getting stats...")
    results[category] = {
        "BP": get_stats(expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_bp),
        "BP(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_bp_sw
        ),
        "DMemBP(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_dmembp_sw
        ),
        "MWPM": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_mwpm
        ),
        "MWPM(SW)": get_stats(
            expmt.chkmat, expmt.obsmat, syndromes, observables, ehat_mwpm_sw
        ),
    }
    print("-" * 100)

print("Data collection complete!")
# Out:
# Collecting data for rounds=10
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for rounds=20
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for rounds=30
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for rounds=40
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Collecting data for rounds=50
# Decoding with BP...
# Decoding with BP(SW)...
# Decoding with DMemBP(SW)...
# Decoding with MWPM...
# Decoding with MWPM(SW)...
# Getting stats...
# ----------------------------------------------------------------------------------------------------
# Data collection complete!

# %%
bar_plot_stats(results)

# %%
stacked_bar_plot_stats(results)
