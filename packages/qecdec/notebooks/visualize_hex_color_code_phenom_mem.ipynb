# %%
from qecdec.experiments import HexColorCode_Phenom_Memory

# %%
def draw_tiles(expmt: HexColorCode_Phenom_Memory, scaling: float = 20):
    import drawsvg as draw

    width = (max(q.real for q in expmt.sites) + 2) * scaling
    height = (max(q.imag for q in expmt.sites) + 2) * scaling

    d = draw.Drawing(width, height, origin=(-scaling, -scaling))

    colors = ["red", "green", "blue"]

    for t in expmt.tiles:
        p = draw.Path(fill=colors[t.color], stroke="black")
        p.M(t.sites[0].real * scaling, t.sites[0].imag * scaling)
        for q in t.sites[1:]:
            p.L(q.real * scaling, q.imag * scaling)
        p.Z()
        d.append(p)

    for q in expmt.sites:
        d.append(
            draw.Circle(
                cx=q.real * scaling,
                cy=q.imag * scaling,
                r=0.3 * scaling,
                fill="black",
            )
        )
        d.append(
            draw.Text(
                str(expmt.site2ind[q]),
                font_size=0.5 * scaling,
                x=q.real * scaling,
                y=q.imag * scaling,
                center=True,
                fill="white",
            )
        )

    return d

# %%
expmt = HexColorCode_Phenom_Memory(
    d=5,
    rounds=5,
    basis="Y",
    depolarizing_error_rate=0.001,
    meas_error_rate=0.005,
)

draw_tiles(expmt)

# %%
expmt.circuit.diagram("timeline")
# Out:
# <svg viewBox="0 0 5408 1312"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L5376,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L5376,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L5376,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L5376,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L5376,320 " stroke="black"/>
# ...

# %%
expmt.circuit.diagram("detslice")
# Out:
# <svg viewBox="0 0 1238.4 963.2" xmlns="http://www.w3.org/2000/svg">
# <g id="slice:1:3.5_1_0:2">
# <path d="M713.6,48 L745.6,16 L777.6,16 L809.6,48 L777.6,80 L745.6,80 L713.6,48" stroke="none" fill-opacity="0.75" fill="#FF4040"/>
# <path d="M713.6,48 L745.6,16 L777.6,16 L809.6,48 L777.6,80 L745.6,80 L713.6,48" stroke="black" fill="none"/>
# </g>
# <g id="slice:5:5.5_2_0:2">
# <path d="M777.6,80 L809.6,48 L841.6,48 L873.6,80 L841.6,112 L809.6,112 L777.6,80" stroke="none" fill-opacity="0.75" fill="#FF4040"/>
# <path d="M777.6,80 L809.6,48 L841.6,48 L873.6,80 L841.6,112 L809.6,112 L777.6,80" stroke="black" fill="none"/>
# </g>
# <g id="slice:6:3.5_3_0:2">
# <path d="M713.6,112 L745.6,80 L777.6,80 L809.6,112 L777.6,144 L745.6,144 L713.6,112" stroke="none" fill-opacity="0.75" fill="#FF4040"/>
# <path d="M713.6,112 L745.6,80 L777.6,80 L809.6,112 L777.6,144 L745.6,144 L713.6,112" stroke="black" fill="none"/>
# </g>
# <g id="slice:10:3.5_1_0:2">
# ...
